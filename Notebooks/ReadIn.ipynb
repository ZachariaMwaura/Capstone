# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/zachariamwaura/Downloads/Disability_and_Health_Data_System__DHDS__20241120.csv', index_col=False)
df.info()
# Out:
# /var/folders/0_/jyfznr0x5q53rj2pvwf26qbw0000gn/T/ipykernel_15087/3588112015.py:1: DtypeWarning: Columns (0,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/zachariamwaura/Downloads/Disability_and_Health_Data_System__DHDS__20241120.csv', index_col=False)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751072 entries, 0 to 751071
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Rowid                       621902 non-null  object
#  1   Year                        751072 non-null  int64
#  2   LocationAbbr                751072 non-null  object
#  3   LocationDesc                751072 non-null  object
#  4   DataSource                  751072 non-null  object
#  5   Category                    751072 non-null  object
#  6   Indicator                   751072 non-null  object
# ...

# %%
df.head(10).T
# Out:
#                                                                             0  \
# Rowid                                     2019~11~JOB01~JOB~DISTYPE~SELFDIS~~
# Year                                                                     2019
# LocationAbbr                                                               DC
# LocationDesc                                             District of Columbia
# DataSource                                                              BRFSS
# Category                                                         Demographics
# Indicator                   Employment status among adults 18 years of age...
# Response                                                             Employed
# Data_Value_Unit                                                             %
# Data_Value_Type                                       Age-adjusted Prevalence
# Data_Value                                                                NaN
# ...

# %%
df['Year'].min(), df['Year'].max()
# Out:
# (2016, 2022)

# %%
df['Year'].value_counts()
# Out:
# Year
# 2017    112640
# 2016    111540
# 2019    107856
# 2020    106752
# 2018    106752
# 2022    106716
# 2021     98816
# Name: count, dtype: int64

# %%
df = pd.read_excel('/Users/zachariamwaura/Downloads/Custom Table_ Civilians Living in the Community for the United States and States, by Disability Status_ 2022download.xlsx', index_col=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                55 non-null     object
#  1   Disability - Total                   55 non-null     object
#  2   Disability - Total.1                 55 non-null     object
#  3   Disability - Total.2                 55 non-null     object
#  4   Disability - Living in Poverty       55 non-null     object
#  5   Disability - Living in Poverty.1     55 non-null     object
#  6   Disability - Living in Poverty.2     55 non-null     object
#  7   Disability - Living in Poverty.3     55 non-null     object
#  8   Disability - Living in Poverty.4     55 non-null     object
#  9   No Disability - Total                55 non-null     object
#  10  No Disability - Total.1              55 non-null     object
# ...
